# %% [markdown]
# # Leap, Prime, Even Odd Numbers and Palindrome to check

# %%
class Nat:
    def __init__(self):
        self.lap = lap
    def lap():
        year = int(input("Enter The Year "))
        if (year%400 == 0) or (year%4 == 0) and (year%100 != 0):
            print(" Leap Year ")
        else:
            print("Not Leap Year")

# %%
def prime(num):
    if num <= 1:
        print("Number is Not Prime ")
    elif num > 1:
        for i in range(2, int(num ** 0.5) + 1):
            if num % i == 0:
                print("Not Prime")
                break 
        else:

            print("Prime")
    else:
        print("Number is Not Prime ")

# %%
prime(20)
# Out:
# Not Prime

# %%
a = Nat

# %%
a.lap()

# %%
num = 45

# %%
year = int(input("Enter The Year "))
if (year%400 == 0) or (year%4 == 0) and (year%100 != 0):
    print(" Leap Year ")
else:
    print("Not Leap Year")

# %%
def leap_year():
    year = int(input("Enter The Year "))
    if (year%400 == 0) or (year%4 == 0) and (year%100 != 0):
        print(" Leap Year ")
    else:
        print("Not Leap Year")

# %%
leap_year()

# %%
a = leap1

# %%
a.lap()

# %%
class Leap1:
    def __init__(self):
        pass
    
    def check_leap_year(self):
        year = int(input("Enter The Year: "))
        if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
            print(f"{year} is a Leap Year.")
        else:
            print(f"{year} is Not a Leap Year.")
    def auto(self):
        while True:
            self.check_leap_year()
            


a = Leap1()


a.auto()
# Out:
# Enter The Year: 2000
# 2000 is a Leap Year.
# Enter The Year: 3000
# 3000 is Not a Leap Year.
# Enter The Year: 2020
# 2020 is a Leap Year.
# Enter The Year: 4000
# 4000 is a Leap Year.
# Enter The Year: 12365
# 12365 is Not a Leap Year.
# Enter The Year: 26523
# 26523 is Not a Leap Year.

# %%
class leap:
    def __init__(self):
        pass
    def leap_year(self):
        year = int(input("Enter a year "))
        if (year%400==0) or (year%4==0) and (year%100!=0):
            print(f"{year} is a Leap year.")
        else:
            print(f"{year} is not  Leap year.")
    def auto(self):
        while True:
            
            self.leap_year()

a = leap() 
a.auto()
# Out:
# Enter a year 30000
# 30000 is a Leap year.
# Enter a year 200000
# 200000 is a Leap year.

# %%
class Prime2:
    def __init__(self):
        pass
        
    def display(self):
        print(''' 1 : Yes, 2 : No''')
    
    def prime(num):
        num = int(input('Enter the Number')) 
        if num <= 1:
            print("Number is Not Prime ")
        elif num > 1:
            for i in range(2, int(num ** 0.5) + 1):
                if num % i == 0:
                    print("Not Prime")
                    break 
            else:

                print("Prime")
        else:
            print("Number is Not Prime ")
    def auto(self):
        
        while True:
            self.display()
            inp = int(input('want to know: '))
            if inp == 1:
                self.prime()
            else:
                break
            
            


a = Prime2()


a.auto()
# Out:
#  1 : Yes, 2 : No
# want to know: 3

# %%
Number = int(input("Enter a number "))
for num in range(1, Number):
    if Number <= 1: 
        print("Not Prime")
    else:
        is_prime = True
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            print(num,'not Prime')
            break
    if is_prime:
        print(num, 'is prime')
# Out:
# Enter a number 101
# 1 is prime
# 2 is prime
# 3 is prime
# 4 not Prime
# 5 is prime
# 6 not Prime
# 7 is prime
# 8 not Prime
# 9 not Prime
# 10 not Prime
# 11 is prime
# 12 not Prime
# 13 is prime
# 14 not Prime
# 15 not Prime
# 16 not Prime
# 17 is prime
# 18 not Prime
# 19 is prime
# 20 not Prime
# 21 not Prime
# 22 not Prime
# 23 is prime
# 24 not Prime
# 25 not Prime
# 26 not Prime
# 27 not Prime
# 28 not Prime
# 29 is prime
# 30 not Prime
# 31 is prime
# 32 not Prime
# 33 not Prime
# 34 not Prime
# 35 not Prime
# 36 not Prime
# 37 is prime
# 38 not Prime
# 39 not Prime
# 40 not Prime
# 41 is prime
# 42 not Prime
# 43 is prime
# 44 not Prime
# 45 not Prime
# 46 not Prime
# 47 is prime
# 48 not Prime
# 49 not Prime
# 50 not Prime
# 51 not Prime
# 52 not Prime
# 53 is prime
# 54 not Prime
# 55 not Prime
# 56 not Prime
# 57 not Prime
# 58 not Prime
# 59 is prime
# 60 not Prime
# 61 is prime
# 62 not Prime
# 63 not Prime
# 64 not Prime
# 65 not Prime
# 66 not Prime
# 67 is prime
# 68 not Prime
# 69 not Prime
# 70 not Prime
# 71 is prime
# 72 not Prime
# 73 is prime
# 74 not Prime
# 75 not Prime
# 76 not Prime
# 77 not Prime
# 78 not Prime
# 79 is prime
# 80 not Prime
# 81 not Prime
# 82 not Prime
# 83 is prime
# 84 not Prime
# 85 not Prime
# 86 not Prime
# 87 not Prime
# 88 not Prime
# 89 is prime
# 90 not Prime
# 91 not Prime
# 92 not Prime
# 93 not Prime
# 94 not Prime
# 95 not Prime
# 96 not Prime
# 97 is prime
# 98 not Prime
# 99 not Prime
# 100 not Prime

# %%
for num in range(1, 101):
    is_prime = True
    
    if num <= 1:
        print(num, 'not prime')
    else:
        for i in range(2, num):
            if num % i == 0:
                is_prime = False
                print(num, 'not Prime')
                break

        if is_prime:
            print(num, 'is prime')
# Out:
# 1 not prime
# 2 is prime
# 3 is prime
# 4 not Prime
# 5 is prime
# 6 not Prime
# 7 is prime
# 8 not Prime
# 9 not Prime
# 10 not Prime
# 11 is prime
# 12 not Prime
# 13 is prime
# 14 not Prime
# 15 not Prime
# 16 not Prime
# 17 is prime
# 18 not Prime
# 19 is prime
# 20 not Prime
# 21 not Prime
# 22 not Prime
# 23 is prime
# 24 not Prime
# 25 not Prime
# 26 not Prime
# 27 not Prime
# 28 not Prime
# 29 is prime
# 30 not Prime
# 31 is prime
# 32 not Prime
# 33 not Prime
# 34 not Prime
# 35 not Prime
# 36 not Prime
# 37 is prime
# 38 not Prime
# 39 not Prime
# 40 not Prime
# 41 is prime
# 42 not Prime
# 43 is prime
# 44 not Prime
# 45 not Prime
# 46 not Prime
# 47 is prime
# 48 not Prime
# 49 not Prime
# 50 not Prime
# 51 not Prime
# 52 not Prime
# 53 is prime
# 54 not Prime
# 55 not Prime
# 56 not Prime
# 57 not Prime
# 58 not Prime
# 59 is prime
# 60 not Prime
# 61 is prime
# 62 not Prime
# 63 not Prime
# 64 not Prime
# 65 not Prime
# 66 not Prime
# 67 is prime
# 68 not Prime
# 69 not Prime
# 70 not Prime
# 71 is prime
# 72 not Prime
# 73 is prime
# 74 not Prime
# 75 not Prime
# 76 not Prime
# 77 not Prime
# 78 not Prime
# 79 is prime
# 80 not Prime
# 81 not Prime
# 82 not Prime
# 83 is prime
# 84 not Prime
# 85 not Prime
# 86 not Prime
# 87 not Prime
# 88 not Prime
# 89 is prime
# 90 not Prime
# 91 not Prime
# 92 not Prime
# 93 not Prime
# 94 not Prime
# 95 not Prime
# 96 not Prime
# 97 is prime
# 98 not Prime
# 99 not Prime
# 100 not Prime

# %%
tup = (2)

# %%
type(tup)
# Out:
# int

# %%
number = int(input('Enter Number'))

for num in range(1, number + 1):
    is_prime = True
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            print(num, 'not Prime')
            break
    if num <= 1:
        print(num, 'not prime')
    elif is_prime:
        print(num, 'is prime')
# Out:
# Enter Number101
# 1 not prime
# 2 is prime
# 3 is prime
# 4 not Prime
# 5 is prime
# 6 not Prime
# 7 is prime
# 8 not Prime
# 9 not Prime
# 10 not Prime
# 11 is prime
# 12 not Prime
# 13 is prime
# 14 not Prime
# 15 not Prime
# 16 not Prime
# 17 is prime
# 18 not Prime
# 19 is prime
# 20 not Prime
# 21 not Prime
# 22 not Prime
# 23 is prime
# 24 not Prime
# 25 not Prime
# 26 not Prime
# 27 not Prime
# 28 not Prime
# 29 is prime
# 30 not Prime
# 31 is prime
# 32 not Prime
# 33 not Prime
# 34 not Prime
# 35 not Prime
# 36 not Prime
# 37 is prime
# 38 not Prime
# 39 not Prime
# 40 not Prime
# 41 is prime
# 42 not Prime
# 43 is prime
# 44 not Prime
# 45 not Prime
# 46 not Prime
# 47 is prime
# 48 not Prime
# 49 not Prime
# 50 not Prime
# 51 not Prime
# 52 not Prime
# 53 is prime
# 54 not Prime
# 55 not Prime
# 56 not Prime
# 57 not Prime
# 58 not Prime
# 59 is prime
# 60 not Prime
# 61 is prime
# 62 not Prime
# 63 not Prime
# 64 not Prime
# 65 not Prime
# 66 not Prime
# 67 is prime
# 68 not Prime
# 69 not Prime
# 70 not Prime
# 71 is prime
# 72 not Prime
# 73 is prime
# 74 not Prime
# 75 not Prime
# 76 not Prime
# 77 not Prime
# 78 not Prime
# 79 is prime
# 80 not Prime
# 81 not Prime
# 82 not Prime
# 83 is prime
# 84 not Prime
# 85 not Prime
# 86 not Prime
# 87 not Prime
# 88 not Prime
# 89 is prime
# 90 not Prime
# 91 not Prime
# 92 not Prime
# 93 not Prime
# 94 not Prime
# 95 not Prime
# 96 not Prime
# 97 is prime
# 98 not Prime
# 99 not Prime
# 100 not Prime
# 101 is prime

# %%
number = int(input('Enter Number'))

for num in range(1, number + 1):
    is_prime = True
    for i in range(2, num):
        if num % i == 0:
            is_prime = False
            print(num, 'not Prime')
            break
    if num <= 1:
        print(num, 'not prime')
    else:
        print(num, 'is prime')
# Out:
# Enter Number25
# 1 not prime
# 2 is prime
# 3 is prime
# 4 not Prime
# 4 is prime
# 5 is prime
# 6 not Prime
# 6 is prime
# 7 is prime
# 8 not Prime
# 8 is prime
# 9 not Prime
# 9 is prime
# 10 not Prime
# 10 is prime
# 11 is prime
# 12 not Prime
# 12 is prime
# 13 is prime
# 14 not Prime
# 14 is prime
# 15 not Prime
# 15 is prime
# 16 not Prime
# 16 is prime
# 17 is prime
# 18 not Prime
# 18 is prime
# 19 is prime
# 20 not Prime
# 20 is prime
# 21 not Prime
# 21 is prime
# 22 not Prime
# 22 is prime
# 23 is prime
# 24 not Prime
# 24 is prime
# 25 not Prime
# 25 is prime

# %%
 number = int(input('Enter Number'))

for num in range(1, number + 1):
   
    
    if num <= 1:
        print(num, 'not prime')
    else:
        print(num, 'is prime')
    for i in range(2, num):
        if num % i == 0:
          
            print(num, 'not Prime')
            break
# Out:
# Enter Number101
# 1 not prime
# 2 is prime
# 3 is prime
# 4 is prime
# 4 not Prime
# 5 is prime
# 6 is prime
# 6 not Prime
# 7 is prime
# 8 is prime
# 8 not Prime
# 9 is prime
# 9 not Prime
# 10 is prime
# 10 not Prime
# 11 is prime
# 12 is prime
# 12 not Prime
# 13 is prime
# 14 is prime
# 14 not Prime
# 15 is prime
# 15 not Prime
# 16 is prime
# 16 not Prime
# 17 is prime
# 18 is prime
# 18 not Prime
# 19 is prime
# 20 is prime
# 20 not Prime
# 21 is prime
# 21 not Prime
# 22 is prime
# 22 not Prime
# 23 is prime
# 24 is prime
# 24 not Prime
# 25 is prime
# 25 not Prime
# 26 is prime
# 26 not Prime
# 27 is prime
# 27 not Prime
# 28 is prime
# 28 not Prime
# 29 is prime
# 30 is prime
# 30 not Prime
# 31 is prime
# 32 is prime
# 32 not Prime
# 33 is prime
# 33 not Prime
# 34 is prime
# 34 not Prime
# 35 is prime
# 35 not Prime
# 36 is prime
# 36 not Prime
# 37 is prime
# 38 is prime
# 38 not Prime
# 39 is prime
# 39 not Prime
# 40 is prime
# 40 not Prime
# 41 is prime
# 42 is prime
# 42 not Prime
# 43 is prime
# 44 is prime
# 44 not Prime
# 45 is prime
# 45 not Prime
# 46 is prime
# 46 not Prime
# 47 is prime
# 48 is prime
# 48 not Prime
# 49 is prime
# 49 not Prime
# 50 is prime
# 50 not Prime
# 51 is prime
# 51 not Prime
# 52 is prime
# 52 not Prime
# 53 is prime
# 54 is prime
# 54 not Prime
# 55 is prime
# 55 not Prime
# 56 is prime
# 56 not Prime
# 57 is prime
# 57 not Prime
# 58 is prime
# 58 not Prime
# 59 is prime
# 60 is prime
# 60 not Prime
# 61 is prime
# 62 is prime
# 62 not Prime
# 63 is prime
# 63 not Prime
# 64 is prime
# 64 not Prime
# 65 is prime
# 65 not Prime
# 66 is prime
# 66 not Prime
# 67 is prime
# 68 is prime
# 68 not Prime
# 69 is prime
# 69 not Prime
# 70 is prime
# 70 not Prime
# 71 is prime
# 72 is prime
# 72 not Prime
# 73 is prime
# 74 is prime
# 74 not Prime
# 75 is prime
# 75 not Prime
# 76 is prime
# 76 not Prime
# 77 is prime
# 77 not Prime
# 78 is prime
# 78 not Prime
# 79 is prime
# 80 is prime
# 80 not Prime
# 81 is prime
# 81 not Prime
# 82 is prime
# 82 not Prime
# 83 is prime
# 84 is prime
# 84 not Prime
# 85 is prime
# 85 not Prime
# 86 is prime
# 86 not Prime
# 87 is prime
# 87 not Prime
# 88 is prime
# 88 not Prime
# 89 is prime
# 90 is prime
# 90 not Prime
# 91 is prime
# 91 not Prime
# 92 is prime
# 92 not Prime
# 93 is prime
# 93 not Prime
# 94 is prime
# 94 not Prime
# 95 is prime
# 95 not Prime
# 96 is prime
# 96 not Prime
# 97 is prime
# 98 is prime
# 98 not Prime
# 99 is prime
# 99 not Prime
# 100 is prime
# 100 not Prime
# 101 is prime

# %%
tup = (2)

# %%
type(tup)
# Out:
# tuple

# %%
primes = [num for num in range(2,11) if all(num % i != 0 for i in range (2,int(num**0.5)+1))]
primes
# Out:
# [2, 3, 5, 7]

# %%
def is_prime(n):
    for number in range(2,n+1):
        if number <= 2:
            print(number," is Prime")
        for i in range(2,number):
            if number%i == 0:
                print(number,"not Prime")
                break
            else:
                print(number,"prime")
                break
                
number = int(input("Enter a Number"))
is_prime(10)
# Out:
# Enter a Number10
# 2  is Prime
# 3 prime
# 4 not Prime
# 5 prime
# 6 not Prime
# 7 prime
# 8 not Prime
# 9 prime
# 10 not Prime

# %%
def is_prime(n):
    for num in range(2, number + 1):
        is_prime = True  
    
    if num <= 1:
        is_prime = False
    else:
        for i in range(2, num):
            if num % i == 0:
                is_prime = False
                break
    
    if is_prime:
        print(num, 'is prime')
    else:
        print(num, 'not prime')
number = int(input("Enter a Number"))
is_prime(number)
# Out:
# Enter a Number2
# 2 is prime

# %%
# Out:
# Enter Number : 1
# not Prime
# 1 not prime

# %%
def is_prime(number):
        

        for num in range(1, number + 1):


            if num <= 1:

                print(num, 'not Prime')
            else:
                for i in range(2, num):
                    if num % i == 0:

                        print(num, 'no Prime')
                        break
                    else:
                        print(num, 'Prime')
number = int(input('Enter Number'))
# Out:
# Enter Number101

# %%
is_prime(number)
# Out:
# 1 not Prime
# 3 Prime
# 4 no Prime
# 5 Prime
# 5 Prime
# 5 Prime
# 6 no Prime
# 7 Prime
# 7 Prime
# 7 Prime
# 7 Prime
# 7 Prime
# 8 no Prime
# 9 Prime
# 9 no Prime
# 10 no Prime
# 11 Prime
# 11 Prime
# 11 Prime
# 11 Prime
# 11 Prime
# 11 Prime
# 11 Prime
# 11 Prime
# 11 Prime
# 12 no Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 13 Prime
# 14 no Prime
# 15 Prime
# 15 no Prime
# 16 no Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 17 Prime
# 18 no Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 19 Prime
# 20 no Prime
# 21 Prime
# 21 no Prime
# 22 no Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 23 Prime
# 24 no Prime
# 25 Prime
# 25 Prime
# 25 Prime
# 25 no Prime
# 26 no Prime
# 27 Prime
# 27 no Prime
# 28 no Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 29 Prime
# 30 no Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 31 Prime
# 32 no Prime
# 33 Prime
# 33 no Prime
# 34 no Prime
# 35 Prime
# 35 Prime
# 35 Prime
# 35 no Prime
# 36 no Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 37 Prime
# 38 no Prime
# 39 Prime
# 39 no Prime
# 40 no Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 41 Prime
# 42 no Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 43 Prime
# 44 no Prime
# 45 Prime
# 45 no Prime
# 46 no Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 47 Prime
# 48 no Prime
# 49 Prime
# 49 Prime
# 49 Prime
# 49 Prime
# 49 Prime
# 49 no Prime
# 50 no Prime
# 51 Prime
# 51 no Prime
# 52 no Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 53 Prime
# 54 no Prime
# 55 Prime
# 55 Prime
# 55 Prime
# 55 no Prime
# 56 no Prime
# 57 Prime
# 57 no Prime
# 58 no Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 59 Prime
# 60 no Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 61 Prime
# 62 no Prime
# 63 Prime
# 63 no Prime
# 64 no Prime
# 65 Prime
# 65 Prime
# 65 Prime
# 65 no Prime
# 66 no Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 67 Prime
# 68 no Prime
# 69 Prime
# 69 no Prime
# 70 no Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 71 Prime
# 72 no Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 73 Prime
# 74 no Prime
# 75 Prime
# 75 no Prime
# 76 no Prime
# 77 Prime
# 77 Prime
# 77 Prime
# 77 Prime
# 77 Prime
# 77 no Prime
# 78 no Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 79 Prime
# 80 no Prime
# 81 Prime
# 81 no Prime
# 82 no Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 83 Prime
# 84 no Prime
# 85 Prime
# 85 Prime
# 85 Prime
# 85 no Prime
# 86 no Prime
# 87 Prime
# 87 no Prime
# 88 no Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 89 Prime
# 90 no Prime
# 91 Prime
# 91 Prime
# 91 Prime
# 91 Prime
# 91 Prime
# 91 no Prime
# 92 no Prime
# 93 Prime
# 93 no Prime
# 94 no Prime
# 95 Prime
# 95 Prime
# 95 Prime
# 95 no Prime
# 96 no Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 97 Prime
# 98 no Prime
# 99 Prime
# 99 no Prime
# 100 no Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime
# 101 Prime

# %%
# Out:
# Enter Number10
# 1 not Prime
# 2 Prime
# 3 Prime
# 4 no Prime
# 5 Prime
# 6 no Prime
# 7 Prime
# 8 no Prime
# 9 no Prime
# 10 no Prime
